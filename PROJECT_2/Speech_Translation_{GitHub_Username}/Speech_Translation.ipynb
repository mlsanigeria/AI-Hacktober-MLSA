# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/samuelbamgbola/Documents/AI-Hacktober-MLSA/PROJECT_2/Speech_Translation_{GitHub_Username}/Speech_Translation.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/Users/samuelbamgbola/Documents/AI-Hacktober-MLSA/PROJECT_2/Speech_Translation_%7BGitHub_Username%7D/Speech_Translation.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#
# File ~/Documents/AI-Hacktober-MLSA/lib/python3.9/site-packages/pandas/__init__.py:46
#      43 # let init-time option registration happen
#      44 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 46 from pandas.core.api import (
#      47     # dtype
#      48     ArrowDtype,
#      49     Int8Dtype,
#      50     Int16Dtype,
#      51     Int32Dtype,
#      52     Int64Dtype,
#      53     UInt8Dtype,
#      54     UInt16Dtype,
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Failed to start the Kernel 'AI-Hacktober-MLSA (Python 3.9.13)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. ENOSPC: no space left on device, write

# %%
import streamlit as st
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /Users/samuelbamgbola/Documents/AI-Hacktober-MLSA/PROJECT_2/Speech_Translation_{GitHub_Username}/Speech_Translation.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/Users/samuelbamgbola/Documents/AI-Hacktober-MLSA/PROJECT_2/Speech_Translation_%7BGitHub_Username%7D/Speech_Translation.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import streamlit as st
#
# File ~/Documents/AI-Hacktober-MLSA/lib/python3.9/site-packages/streamlit/__init__.py:55
#      52 # Give the package a version.
#      53 __version__ = _STREAMLIT_VERSION_STRING
# ...

# %%
# !pip install streamlit

# %%
# !pip install pandas

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /Users/samuelbamgbola/Documents/AI-Hacktober-MLSA/PROJECT_2/Speech_Translation_{GitHub_Username}/Speech_Translation.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/samuelbamgbola/Documents/AI-Hacktober-MLSA/PROJECT_2/Speech_Translation_%7BGitHub_Username%7D/Speech_Translation.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#
# File ~/Documents/AI-Hacktober-MLSA/lib/python3.9/site-packages/pandas/__init__.py:46
#      43 # let init-time option registration happen
# ...

# %%
import pandas as pd

# %%
import streamlit as st
